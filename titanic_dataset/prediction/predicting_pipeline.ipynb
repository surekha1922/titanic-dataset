# %%
import pickle
import numpy as np

# %%
#predicting without pipeline
ohe_sex=pickle.load(open("titanic_dataset/models/ohe_sex.pkl","rb"))
ohe_embarked=pickle.load(open("titanic_dataset/models/ohe_embarked.pkl","rb"))
clf=pickle.load(open("titanic_dataset/models/clf.pkl","rb"))

# %%
#Test input
test_ip = np.array([2,"male",31.0,0,0,10.5,"S"],dtype=object).reshape(1,7)

# %%
test_ip_sex = ohe_sex.transform(test_ip[:,1].reshape(1,1))
# Out:
# /home/rgukt/yes/lib/python3.11/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but OneHotEncoder was fitted with feature names
#   warnings.warn(

# %%
test_ip_embarked = ohe_embarked.transform(test_ip[:,-1].reshape(1,1))
# Out:
# /home/rgukt/yes/lib/python3.11/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but OneHotEncoder was fitted with feature names
#   warnings.warn(

# %%
test_ip_age = test_ip[:,2].reshape(1,1)

# %%
test_inp_trans = np.concatenate((test_ip[:,[0,3,4,5]],test_ip_sex,test_ip_age,test_ip_embarked),axis=1)

# %%
#So as we see we are repeating the same steps so we are using pipelining

# %%
#Predicitng using pipeline
pipe = pickle.load(open("titanic_dataset/models/pipeline.pkl","rb"))

# %%
pipe.predict(test_ip)
# Out:
# /home/rgukt/yes/lib/python3.11/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but SimpleImputer was fitted with feature names
#   warnings.warn(
# /home/rgukt/yes/lib/python3.11/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but SimpleImputer was fitted with feature names
#   warnings.warn(
# array([0])
